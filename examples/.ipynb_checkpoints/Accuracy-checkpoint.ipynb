# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import buildtools as bt

# %%
xy, ab = np.random.rand(10,2), np.random.rand(10,2)

# %%
bt.plot_pairs(xy,ab)

# %%
bt.bdr(xy,ab)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18556\3633063523.py in <cell line: 1>()
# ----> 1 bt.bdr(xy,ab)
#
# ~\anaconda3\envs\neil\lib\site-packages\buildtools\buildtools.py in bdr(XY, AB)
#     199     DI = np.sqrt(1-rsquare)                        # This is how DI is computed in sample and equation 12, page 479
#     200     F = ((2*len(A) - 4) / (4 - 2)) * (rsquare / (1-rsquare))
# --> 201     P = 1 - stats.f.cdf(F,2,2*len(A)-4)
#     202
#     203     result = {}
#
# NameError: name 'stats' is not defined
