# %%
import buildtools as bt

import numpy as np
import matplotlib.pyplot as plt
import pprint

# %%
# Case 1: Randomly Paired Data

# %%
n_xy = 10
n_ab = 10

xy,ab = np.random.rand(n_xy,2), np.random.rand(n_ab,2)
bt.plot_pairs(xy,ab)

# This calculates all relevant statistics; t is a distance threshold
result = bt.build_score(xy,ab,t=.1)
pprint.pprint(result)
# Out:
# {'F1': nan,
#  'FN': 10,
#  'FP': 10,
#  'TP': 0,
#  'bdr': {'D': 0.6294690002269381,
#          'DI': 0.530725863097963,
#          'Dmax': 1.1860529964614686,
#          'F': 20.402036617687376,
#          'P': 3.962087221387467e-05,
#          'aPrime': array([0.81682539, 0.5694816 , 0.40208563, 0.27956082, 0.32112206,
#        0.94274035, 0.2829963 , 0.45583446, 0.7795626 , 0.45305661]),
#          'alpha1': 0.1562667646866933,
#          'alpha2': 0.07140563996138177,
#          'bPrime': array([0.69729409, 0.57697472, 0.64444197, 0.14550093, 0.11930131,
#        0.66363488, 0.28405822, 0.74169735, 0.34446654, 0.59953246]),
#          'beta1': 0.7185375906963173,
#          'beta2': -0.10063279575464139,
#          'rsquare': 0.7183300582389223,
#          'scale': 0.7255502937943473,
#          'theta': -7.972545705422672},
#  'chamfer_ab_to_xy': 0.1972293483275393,
#  'chamfer_ratio': -0.07860557334922635,
#  'chamfer_xy_to_ab': 0.1828558587131287,
#  'col': array([6, 4, 0, 3, 9, 5, 8, 2, 7, 1], dtype=int64),
#  'distance': array([0.14418674, 0.37403991, 0.29527241, 0.34096656, 0.13057757,
#        0.38459062, 0.11677238, 0.26167483, 0.35595815, 0.38823304]),
#  'n': 20,
#  'precision': 0.0,
#  'recall': 0.0}
# C:\Users\thoma\anaconda3\envs\build\lib\site-packages\buildtools\buildtools.py:545: RuntimeWarning: invalid value encountered in double_scalars
#   F1 = 2 * (precision * recall) / (precision + recall)

# %% [markdown]
# # Case 2: Equal Numbers of XY (true) and AB (detected)

# %%
n_xy = 10
n_ab = 10

xy,ab = np.random.rand(n_xy,2), np.random.rand(n_ab,2)
result = bt.build_score(xy,ab,t=.1)
pprint.pprint(result)

bt.plot_pairs(xy,ab[result['col']])
# Out:
# {'F1': 0.10000000000000002,
#  'FN': 9,
#  'FP': 9,
#  'TP': 1,
#  'bdr': {'D': 0.26462027993534076,
#          'DI': 0.31209745272825556,
#          'Dmax': 0.8478770897426924,
#          'F': 74.13145920339345,
#          'P': 8.102957971267699e-09,
#          'aPrime': array([0.50150746, 0.79400241, 0.73971354, 0.92864106, 0.81027776,
#        0.55589337, 0.7602708 , 0.63607145, 0.40625642, 0.91007623]),
#          'alpha1': 0.2676176951925737,
#          'alpha2': 0.3966806727730222,
#          'bPrime': array([0.75729856, 0.62802424, 0.31523044, 0.64671966, 0.14211458,
#        0.35615877, 0.33669689, 0.65076546, 0.62469816, 0.65900544]),
#          'beta1': 0.5339892718357359,
#          'beta2': -0.28193138112357286,
#          'rsquare': 0.9025951800005343,
#          'scale': 0.6038458794244643,
#          'theta': -27.832799161998295},
#  'chamfer_ab_to_xy': 0.18351995121679782,
#  'chamfer_ratio': 0.26789398334280357,
#  'chamfer_xy_to_ab': 0.23268384197114278,
#  'col': array([1, 4, 0, 8, 9, 7, 2, 5, 6, 3], dtype=int64),
#  'distance': array([0.33954319, 0.25051051, 0.09646933, 0.25323927, 0.24821665,
#        0.29929385, 0.10384252, 0.28357017, 0.45130635, 0.3701196 ]),
#  'n': 19,
#  'precision': 0.1,
#  'recall': 0.1}

# %% [markdown]
# # Case 3: More observations in ab (simulating noise)

# %%
n_xy = 10
n_ab = 100

xy,ab = np.random.rand(n_xy,2), np.random.rand(n_ab,2)
plt.plot(*ab.T,'x')
ab_paired = ab[col]

bt.plot_pairs(xy,ab_paired)
